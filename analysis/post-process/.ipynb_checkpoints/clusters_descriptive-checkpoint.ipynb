# %%
import pandas as pd
import altair as alt
from altair import datum
import numpy as np
import matplotlib as plt
from datetime import datetime as dt
from scipy.stats import ttest_ind
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ## exploring size of transmission clusters

# %%
new_clus =  "../../mascot_glm/data/kc_clusters_combined_new.tsv"

# %%
clus_df = pd.read_csv(new_clus, sep="\t", parse_dates=  [3])

# %%
clus_df
# Out:
#                                            strain  cluster           location  \
# 0                      USA/WA-UW-21050529358/2021        1  North_King_County
# 1                      USA/WA-UW-21050476716/2021        2  North_King_County
# 2                    USA/WA-UW-2021041397284/2021        3  North_King_County
# 3                    USA/WA-UW-2021041489375/2021        3  North_King_County
# 4      USA/WA-Altius-ALTCOV-NBDJ5QXGCUU6C2F6/2021        3  South_King_County
# ...                                           ...      ...                ...
# 11374               USA/WA-CDC-UW22030161746/2022     1423  North_King_County
# 11375               USA/WA-CDC-UW22030214877/2022     1424  North_King_County
# 11376               USA/WA-CDC-UW22030572755/2022     1424  North_King_County
# 11377               USA/WA-CDC-UW22022865732/2022     1425  North_King_County
# 11378               USA/WA-CDC-UW22022638336/2022     1425  North_King_County
#
#             date  is_unique  new_clusters
# 0     2021-05-05       True             1
# 1     2021-05-04       True             2
# 2     2021-04-13       True             3
# 3     2021-04-14      False             3
# 4     2021-04-27      False             3
# ...          ...        ...           ...
# 11374 2022-03-01       True          5962
# 11375 2022-03-02       True          5963
# 11376 2022-03-05      False          5963
# 11377 2022-02-28       True          5964
# 11378 2022-02-26      False          5964
#
# [11379 rows x 6 columns]

# %%
cluster_counts_n = pd.DataFrame()
cluster_counts_s = pd.DataFrame()
cluster_counts_n['count_clus'] = clus_df[clus_df['location'] =="North_King_County"].new_clusters.value_counts()
cluster_counts_s['count_clus'] = clus_df[clus_df['location'] =="South_King_County"].new_clusters.value_counts()

# %%
cluster_counts_n = cluster_counts_n.reset_index()
cluster_counts_n = cluster_counts_n.rename(columns={"index": "clusid", "count_clus": "size", "location": "Region"})
cluster_counts_s = cluster_counts_s.reset_index()
cluster_counts_s = cluster_counts_s.rename(columns={"index": "clusid", "count_clus": "size", "location": "Region"})

cluster_counts_n["Region"] = "North King County"
cluster_counts_s["Region"] = "South King County"

# %%
concat_clus = pd.concat([ cluster_counts_n, cluster_counts_s], ignore_index=True)
#concat_clus
concat_clus = concat_clus[["size", "Region"]]
#test.to_csv("cluster_distribution.tsv",  sep="\t")

# %%
concat_clus
# Out:
#       size             Region
# 0      149  North King County
# 1      122  North King County
# 2       58  North King County
# 3       48  North King County
# 4       46  North King County
# ...    ...                ...
# 6608     1  South King County
# 6609     1  South King County
# 6610     1  South King County
# 6611     1  South King County
# 6612     1  South King County
#
# [6613 rows x 2 columns]

# %%
df_size = pd.DataFrame(concat_clus.groupby('Region', as_index = False).value_counts())#.reset_index()
df_size['perc'] = df_size.groupby('Region')['count'].apply(lambda x: x/x.sum())

df_size
# Out:
#                Region  size  count      perc
# 0   North King County     1   2999  0.788795
# 1   North King County     2    437  0.114940
# 2   North King County     3    172  0.045239
# 3   North King County     4     57  0.014992
# 4   North King County     5     43  0.011310
# 5   North King County     6     25  0.006575
# 6   North King County     7     15  0.003945
# 7   North King County     8      9  0.002367
# 8   North King County    10      9  0.002367
# 9   North King County    13      5  0.001315
# 10  North King County     9      5  0.001315
# 11  North King County    11      4  0.001052
# 12  North King County    15      4  0.001052
# 13  North King County    12      3  0.000789
# 14  North King County    20      2  0.000526
# 15  North King County    19      2  0.000526
# 16  North King County   149      1  0.000263
# 17  North King County    14      1  0.000263
# 18  North King County    18      1  0.000263
# 19  North King County   122      1  0.000263
# 20  North King County    22      1  0.000263
# 21  North King County    23      1  0.000263
# 22  North King County    27      1  0.000263
# 23  North King County    30      1  0.000263
# 24  North King County    46      1  0.000263
# 25  North King County    48      1  0.000263
# 26  North King County    58      1  0.000263
# 27  South King County     1   2096  0.745642
# 28  South King County     2    371  0.131982
# 29  South King County     3    126  0.044824
# 30  South King County     4     80  0.028460
# 31  South King County     5     41  0.014586
# 32  South King County     6     19  0.006759
# 33  South King County     7     19  0.006759
# 34  South King County     8     14  0.004980
# 35  South King County     9     10  0.003557
# 36  South King County    13      5  0.001779
# 37  South King County    12      5  0.001779
# 38  South King County    10      5  0.001779
# 39  South King County    23      3  0.001067
# 40  South King County    16      3  0.001067
# 41  South King County    29      2  0.000711
# 42  South King County    18      1  0.000356
# 43  South King County   158      1  0.000356
# 44  South King County    59      1  0.000356
# 45  South King County    34      1  0.000356
# 46  South King County    33      1  0.000356
# 47  South King County    32      1  0.000356
# 48  South King County    22      1  0.000356
# 49  South King County    21      1  0.000356
# 50  South King County    20      1  0.000356
# 51  South King County    14      1  0.000356
# 52  South King County    11      1  0.000356
# 53  South King County   283      1  0.000356

# %%
# Out:
# Region
# North King County    1.613361
# South King County    1.865884
# Name: contribution, dtype: float64

# %%
# Out:
# Ttest_indResult(statistic=-1.9757115085592991, pvalue=0.048228979458211675)

# %%
log_clusters =  alt.Chart(df_size).mark_line(opacity = 1, interpolate = "monotone").encode(
    x=alt.X('size:Q', axis=alt.Axis(title="Cluster Size", grid=False)),
    y=alt.Y('perc:Q',  axis=alt.Axis(title="Log Frequency Distribution",labelFontSize= 14, titleFontSize = 12, grid=False, format='%'), scale=alt.Scale(type = "log", zero = True)),
    color = alt.Color("Region:N", legend=alt.Legend(offset = -140,  labelFontSize = 14, titleFontSize = 12))).transform_filter(datum.size < 11).properties(
    width=300,
    height=200
)
log_clusters
# Out:
# alt.Chart(...)

# %%
linear_clusters =  alt.Chart(df_size).mark_line(opacity = 1, interpolate = "monotone").encode(
    x=alt.X('size:Q', axis=alt.Axis(title="Cluster Size", grid=False)),
    y=alt.Y('perc:Q',  axis=alt.Axis(title="Frequency Distribution",labelFontSize= 14, titleFontSize = 12, grid=False, format='%')),
    color = alt.Color("Region:N")).transform_filter(datum.size < 11).properties(
    width=300,
    height=200
)
linear_clusters
# Out:
# alt.Chart(...)

# %%
cluster_count = linear_clusters | log_clusters
cluster_count
# Out:
# alt.HConcatChart(...)

# %%
#calculate mean cluster size
df_size["contribution"] = df_size["size"] * df_size['perc']
df_size.groupby('Region')["contribution"].sum()

# %%
#two sample t test for cluster size 
#define samples
group1 = concat_clus[concat_clus['Region']=='North King County']
group2 = concat_clus[concat_clus['Region']=='South King County']

#perform independent two sample t-test
ttest_ind(group1['size'], group2['size'])

# %% [markdown]
# # now look at number of clusters over time for each region

# %%
date_clus = clus_df.groupby('new_clusters').first().reset_index()

# %%
date_clus
# Out:
#       new_clusters                                      strain  cluster  \
# 0                1                  USA/WA-UW-21050529358/2021        1
# 1                2                  USA/WA-UW-21050476716/2021        2
# 2                3                USA/WA-UW-2021041397284/2021        3
# 3                4                        USA/WA-UW-65398/2021        4
# 4                5                        USA/WA-UW-69277/2021        5
# ...            ...                                         ...      ...
# 5959          5960  USA/WA-Altius-ALTCOV-BEQRS2ML7ZX3EQWJ/2021     1421
# 5960          5961                           USA/WA-S2728/2020     1422
# 5961          5962               USA/WA-CDC-UW22030161746/2022     1423
# 5962          5963               USA/WA-CDC-UW22030214877/2022     1424
# 5963          5964               USA/WA-CDC-UW22022865732/2022     1425
#
#                location       date  is_unique
# 0     North_King_County 2021-05-05       True
# 1     North_King_County 2021-05-04       True
# 2     North_King_County 2021-04-13       True
# 3     North_King_County 2021-02-27       True
# 4     South_King_County 2021-03-26       True
# ...                 ...        ...        ...
# 5959  South_King_County 2021-07-09       True
# 5960  North_King_County 2020-07-08       True
# 5961  North_King_County 2022-03-01       True
# 5962  North_King_County 2022-03-02       True
# 5963  North_King_County 2022-02-28       True
#
# [5964 rows x 6 columns]

# %%
def convert_format(number):
    #date = dt.strptime(number, '%Y-%m-%d')
    date = dt.strftime(number, '%Y-%m')
    return date

# %%
date_clus['year-month'] = date_clus['date'].map(convert_format)

# %%
date_clus
# Out:
#       new_clusters                                      strain  cluster  \
# 0                1                  USA/WA-UW-21050529358/2021        1
# 1                2                  USA/WA-UW-21050476716/2021        2
# 2                3                USA/WA-UW-2021041397284/2021        3
# 3                4                        USA/WA-UW-65398/2021        4
# 4                5                        USA/WA-UW-69277/2021        5
# ...            ...                                         ...      ...
# 5959          5960  USA/WA-Altius-ALTCOV-BEQRS2ML7ZX3EQWJ/2021     1421
# 5960          5961                           USA/WA-S2728/2020     1422
# 5961          5962               USA/WA-CDC-UW22030161746/2022     1423
# 5962          5963               USA/WA-CDC-UW22030214877/2022     1424
# 5963          5964               USA/WA-CDC-UW22022865732/2022     1425
#
#                location       date  is_unique year-month
# 0     North_King_County 2021-05-05       True    2021-05
# 1     North_King_County 2021-05-04       True    2021-05
# 2     North_King_County 2021-04-13       True    2021-04
# 3     North_King_County 2021-02-27       True    2021-02
# 4     South_King_County 2021-03-26       True    2021-03
# ...                 ...        ...        ...        ...
# 5959  South_King_County 2021-07-09       True    2021-07
# 5960  North_King_County 2020-07-08       True    2020-07
# 5961  North_King_County 2022-03-01       True    2022-03
# 5962  North_King_County 2022-03-02       True    2022-03
# 5963  North_King_County 2022-02-28       True    2022-02
#
# [5964 rows x 7 columns]

# %%
date_clus.location[date_clus.location == "North_King_County"] = "North King County"
date_clus.location[date_clus.location == "South_King_County"] = "South King County"
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_25838/1765852014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date_clus.location[date_clus.location == "North_King_County"] = "North King County"
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_25838/1765852014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date_clus.location[date_clus.location == "South_King_County"] = "South King County"

# %%
clust_over_time =  alt.Chart(date_clus).mark_bar(opacity = 1, interpolate='monotone', size = 10).encode(
    alt.X('year-month:T', axis = alt.Axis(grid= False, format = "%B %Y", title = "")),
    alt.Y('count():Q', axis=alt.Axis(title="Number of Local Outbreak Clusters", grid=False, labelFontSize = 14), stack = None), 
    alt.Color("location", legend = None), 
    column= alt.Column("location:N", title = None, spacing = 70, header=alt.Header(labelFontSize = 14))).properties(
    width=300,
    height=200
)

# %%
clus_des = (clust_over_time & cluster_count).resolve_scale(color = "independent")
clus_des
# Out:
# alt.VConcatChart(...)

# %%
clus_des.save("../figures/clust_over_time.html")
