# %%
import argparse
from Bio import SeqIO
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopy.distance
from scipy import stats
import os
import altair as alt
import altair_saver

# %%
alignment = '/Users/miguelparedes/Desktop/gitrepos/kc_puma_build/results/north-america_usa_washington_king-county/aligned.fasta'
metadata = '/Users/miguelparedes/Desktop/gitrepos/kc_puma_build/data/metadata_kc_puma.tsv'

# %%
def strains_mapping(alignment, metadata):
    '''
    Returns dictionary mapping strains to location and sequence.
    Only includes strains with region = Seattle.
    Removes strains with location = '?'.
    '''
    diction = {}
    ambig = ['N', 'R', 'M', 'S', 'Y', 'W', 'K', 'D', 'B', 'H', '-']
    with open(alignment) as align:
        for index, record in enumerate(SeqIO.parse(align, 'fasta')):
            seq = str(record.seq)
            seq = seq.replace('A', '0')
            seq = seq.replace('T', '1')
            seq = seq.replace('G', '2')
            seq = seq.replace('C', '3')
            for letter in ambig:
                    seq = seq.replace(letter, "4")
            seq_array = np.asarray(list(seq), dtype = int)
            diction[record.id] = {'seq' : seq_array, 'location' : ''}
    with open(metadata) as mfile:
        meta_file = pd.read_csv(mfile, sep = '\t')
        for row in meta_file.itertuples():
            if row.location == 'King County':
                if row.strain in diction:
                    diction[row.strain]['ns_kc'] = row.ns_kc
                    diction[row.strain]['location'] = row.location
    mapping = {strains: attributes for strains, attributes in diction.items() if attributes['location'] != '' and attributes['ns_kc'] != "other_King County"}
    #subsetting to only SCAN seqs that have a n/s info
    mapping_df = pd.DataFrame.from_dict(mapping, orient = "index")
    mapping_df = mapping_df.groupby("ns_kc").sample(n=148, random_state=545647) #smashed on keyboard
    mapping_sub = mapping_df.to_dict('index')
    return mapping_sub


def hamming(array1, array2):
    '''
    calculates the number of nucleotide differences per site for each pair while not including those site with ambiguities
    '''
    array1_mask = np.ma.masked_where(array1 > 3, array1)
    array2_mask = np.ma.masked_where(array2 > 3, array2)
    return np.sum(array1_mask != array2_mask)

def genetic_distance(mapping):
    '''
    Returns dictionary containing strain, closest strain, and genetic distance (computed as hamming distance) to closest strain.
    '''
    counter = 0
    interval = 100
    length = len(mapping)
    gen_distance_dict = {}
    seq_dict = {}
    for strainA, attributesA in mapping.items():
        
        
        if counter % interval == 0:
            print("[", end = '')
            for x in range(int(counter/interval)):
                print("-", end = '')
            for x in range(int(length/interval) - int(counter/interval)):
                print(" ", end = '')
            print("]")
        
        gen_distance_low = None
        for strainB, attributesB in mapping.items():
            if strainA != strainB:
                gen_distance = hamming(mapping[strainA]['seq'], mapping[strainB]['seq'])
                if gen_distance_low is None or gen_distance < gen_distance_low:
                    gen_distance_low = gen_distance
                    strain_name = strainB
                    strain_loc = attributesB['ns_kc']
               # seq_dict[strainA] = {'percent missing': percent_missing, 'total length': len_seq}
        gen_distance_dict[strainA] = {'gen_distance' : gen_distance_low, 'kc_loc': attributesA['ns_kc'], 'closest_strain' : strain_name, 'closest_strain_loc': strain_loc}
        
        counter += 1
    return gen_distance_dict

# %%
   #Make dictionary mapping strain to location and sequence
    strains = strains_mapping(alignment, metadata)

    
    #Compute genetic distance for each strain
    gen_distance = genetic_distance(strains)
# Out:
# /Users/miguelparedes/anaconda3/envs/nextstrain/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3236: DtypeWarning: Columns (9,28,38,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(async_code, result, async_=True)):
# [  ]
# [- ]
# [--]

# %%
    mapping_df = pd.DataFrame.from_dict(strains, orient = "index")
    mapping_df = mapping_df.groupby("ns_kc").sample(n=1, random_state=135354) #smashed on keyboard
    mapping_sub = mapping_df.to_dict('index')

# %%
mapping_sub
# Out:
# {'USA/WA-S2848/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2726/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2777/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S590/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3923/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5042/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S1485/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2771/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4124/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2776/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3488/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4410/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2772/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2802/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S1489/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3664/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2709/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3817/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2722/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5035/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5009/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5022/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3754/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2789/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3486/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5008/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4140/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3542/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3751/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5522/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2907/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2857/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2749/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3503/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3812/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2880/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2730/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5045/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4999/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2845/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S1490/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4399/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2728/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5026/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2847/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3504/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4283/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2884/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2765/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5021/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4119/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S594/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3901/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3251/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5006/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3654/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3814/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S591/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4161/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4138/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5546/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5225/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S620/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S290/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3742/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3237/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2863/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2782/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5033/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3813/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4412/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2731/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4667/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S1479/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4401/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5068/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5236/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2805/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S267/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3495/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2713/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3748/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2885/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2831/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5237/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2791/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2715/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2908/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4393/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5015/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S604/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5037/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4130/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4395/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2723/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2712/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2800/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2718/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S300/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2797/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5004/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2804/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3641/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4753/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2849/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2753/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3500/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3555/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2790/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3540/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2729/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S266/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2839/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4670/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2809/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S1486/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4162/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2736/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2867/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2717/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4166/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3755/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4373/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4132/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S1482/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2724/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2833/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3548/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2891/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5532/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2733/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2714/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S593/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4995/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2748/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5020/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4669/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2788/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5073/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5234/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S595/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3811/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4394/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2854/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S4686/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3918/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S2732/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5038/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S3497/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'North_King_County'},
#  'USA/WA-S5507/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3803/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3478/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2851/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2739/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5553/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3489/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2816/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5124/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5019/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4139/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5133/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4683/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2826/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2725/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3492/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4160/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4396/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3499/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4398/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5126/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3659/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5241/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2915/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4675/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2868/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5028/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2785/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2892/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4141/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2834/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S588/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2829/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3249/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4676/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3477/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3547/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2850/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2780/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3553/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3917/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4397/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5013/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5521/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2906/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5538/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4677/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S1487/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S592/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4409/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S606/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3744/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2818/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4411/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4278/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3516/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5025/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5514/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5011/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5014/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5024/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5132/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2737/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5113/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3491/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2758/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4689/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2784/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2843/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3545/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4353/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3764/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4407/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2793/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2890/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2759/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2783/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5547/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2796/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5043/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2744/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3236/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4129/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5102/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S271/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5114/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4663/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4685/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2757/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5506/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4539/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5117/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2734/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S616/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3894/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2811/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5010/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3533/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5066/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3915/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5018/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2740/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4147/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3506/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S1483/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4155/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4170/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2745/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4115/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3498/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5649/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4137/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4164/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2810/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5040/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4666/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5017/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4998/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3525/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3738/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4185/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3532/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4680/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4159/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3473/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2769/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4674/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3531/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3554/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3746/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4127/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3509/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2858/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3246/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2787/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2779/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S289/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4121/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S2864/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5031/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3914/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4163/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4408/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3480/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S3481/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S4154/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S619/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5007/2020': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'},
#  'USA/WA-S5128/2021': {'seq': array([4, 4, 4, ..., 4, 4, 4]),
#   'location': 'King County',
#   'ns_kc': 'South_King_County'}}

# %%
distance_df = pd.DataFrame.from_dict(gen_distance, orient = 'index')

# %%
distance_df
# Out:
#                    gen_distance             kc_loc     closest_strain  \
# USA/WA-S3488/2020             3  North_King_County  USA/WA-S3895/2021
# USA/WA-S2715/2020             1  North_King_County  USA/WA-S2714/2020
# USA/WA-S3812/2021             1  North_King_County  USA/WA-S3813/2021
# USA/WA-S3503/2020             0  North_King_County  USA/WA-S4669/2020
# USA/WA-S3813/2021             0  North_King_County  USA/WA-S3817/2021
# ...                         ...                ...                ...
# USA/WA-S3761/2020             1  South_King_County  USA/WA-S3765/2020
# USA/WA-S5014/2020             6  South_King_County  USA/WA-S2893/2020
# USA/WA-S3471/2020             2  South_King_County  USA/WA-S3499/2020
# USA/WA-S4666/2020            13  South_King_County   USA/WA-S591/2020
# USA/WA-S5012/2020             6  South_King_County  USA/WA-S2833/2020
#
#                   closest_strain_loc
# USA/WA-S3488/2020  South_King_County
# USA/WA-S2715/2020  North_King_County
# USA/WA-S3812/2021  North_King_County
# USA/WA-S3503/2020  North_King_County
# USA/WA-S3813/2021  North_King_County
# ...                              ...
# USA/WA-S3761/2020  South_King_County
# USA/WA-S5014/2020  South_King_County
# USA/WA-S3471/2020  South_King_County
# USA/WA-S4666/2020  North_King_County
# USA/WA-S5012/2020  North_King_County
#
# [296 rows x 4 columns]

# %%
distance_df['trans_pair'] = np.nan
for index, row in distance_df.iterrows():
    if row['kc_loc'] and row['closest_strain_loc'] == 'North_King_County':
        distance_df.loc[index,'trans_pair'] = "NN"
    if row['kc_loc'] and row['closest_strain_loc'] == 'South_King_County':
        distance_df.loc[index,'trans_pair'] = "SS"
    elif row['kc_loc'] != row['closest_strain_loc']: 
        distance_df.loc[index,'trans_pair'] = "NS"

# %%
distance_df['trans_pair'].value_counts()
# Out:
# NN    120
# SS    103
# NS     73
# Name: trans_pair, dtype: int64

# %%
def write_histo(gen_dis_dict, histo = "test_histo.png", table = "test_table.tsv"):
        distance_df = pd.DataFrame.from_dict(gen_distance, orient = 'index')
        fig, ax1 = plt.subplots(figsize = (15, 10))
        ax1.hist(distance_df.gen_distance, bins = len(distance_df.gen_distance), width = 5, align = 'left', color="#4C90C0")
        #ax1.set_xlim(0, 25)
        plt.xlabel('distance (# of nucleotides)', size = '32')
        plt.ylabel('count', size = '32')
        ax1.spines['right'].set_visible(False)
        ax1.spines['top'].set_visible(False)
        ax1.tick_params(axis='both', which='major', labelsize=28)
        ax1.tick_params(axis='both', which='minor', labelsize=28)
        plt.tight_layout()
        fig.savefig(histo)
        plt.close()

# %%
 write_histo(gen_distance, histo = "test2_histo.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-691178577868> in <module>
# ----> 1 write_histo(gen_distance, histo = "test2_histo.png")
#
# NameError: name 'write_histo' is not defined

# %%
distance_df
# Out:
#                    gen_distance             kc_loc     closest_strain  \
# USA/WA-S3488/2020             3  North_King_County  USA/WA-S3895/2021
# USA/WA-S2715/2020             1  North_King_County  USA/WA-S2714/2020
# USA/WA-S3812/2021             1  North_King_County  USA/WA-S3813/2021
# USA/WA-S3503/2020             0  North_King_County  USA/WA-S4669/2020
# USA/WA-S3813/2021             0  North_King_County  USA/WA-S3817/2021
# ...                         ...                ...                ...
# USA/WA-S3761/2020             1  South_King_County  USA/WA-S3765/2020
# USA/WA-S5014/2020             6  South_King_County  USA/WA-S2893/2020
# USA/WA-S3471/2020             2  South_King_County  USA/WA-S3499/2020
# USA/WA-S4666/2020            13  South_King_County   USA/WA-S591/2020
# USA/WA-S5012/2020             6  South_King_County  USA/WA-S2833/2020
#
#                   closest_strain_loc trans_pair
# USA/WA-S3488/2020  South_King_County         SS
# USA/WA-S2715/2020  North_King_County         NN
# USA/WA-S3812/2021  North_King_County         NN
# USA/WA-S3503/2020  North_King_County         NN
# USA/WA-S3813/2021  North_King_County         NN
# ...                              ...        ...
# USA/WA-S3761/2020  South_King_County         SS
# USA/WA-S5014/2020  South_King_County         SS
# USA/WA-S3471/2020  South_King_County         SS
# USA/WA-S4666/2020  North_King_County         NS
# USA/WA-S5012/2020  North_King_County         NS
#
# [296 rows x 5 columns]

# %%
chart = alt.Chart(distance_df).mark_bar().encode(
    alt.X('gen_distance', bin=alt.Bin(extent=[0, 30], step=1)), 
    alt.Color('trans_pair:N'),
    alt.Y("count()", stack="normalize", title='count')

)

text = alt.Chart(distance_df).mark_text(align='center', baseline='middle', dy = 15).encode(
    x=alt.X('gen_distance', bin=alt.Bin(extent=[0, 30], step=1)),
    y=alt.Y('count()', stack="normalize"),
    detail='trans_pair:N',
    text=alt.Text('count()')
)
chart + text
# Out:
# alt.LayerChart(...)

# %%
# chart.save('gen_distance_kc_1_step.png')

# %%
distance_df.gen_distance.value_counts()
# Out:
# 0     77
# 1     58
# 3     20
# 2     19
# 6     18
# 7     18
# 4     15
# 8     14
# 9      8
# 5      7
# 11     7
# 10     6
# 13     6
# 12     5
# 14     5
# 16     3
# 18     3
# 15     2
# 17     2
# 20     2
# 25     1
# 19     1
# 27     1
# Name: gen_distance, dtype: int64

# %%
bins = [-0.01,5, 10, 15, 20, 25, 30]
pd.crosstab(pd.cut(distance_df.gen_distance, bins = bins),distance_df.trans_pair, normalize = 'index')
# Out:
# trans_pair          NN        NS        SS
# gen_distance
# (-0.01, 5.0]  0.412621  0.184466  0.402913
# (5.0, 10.0]   0.396552  0.310345  0.293103
# (10.0, 15.0]  0.333333  0.541667  0.125000
# (15.0, 20.0]  0.571429  0.285714  0.142857
# (25.0, 30.0]  0.000000  1.000000  0.000000

# %%
test =  range(0, 0.001, 0.0001)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-38a4b4fe7333> in <module>
# ----> 1 test =  range(0, 0.001, 0.0001)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
for n in test:
  print(n)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
pd.cut(distance_df.gen_distance, 10
       )
# Out:
# USA/WA-S267/2020      (9.83e-05, 0.000197]
# USA/WA-S266/2020     (-9.83e-07, 9.83e-05]
# USA/WA-S271/2020     (-9.83e-07, 9.83e-05]
# USA/WA-S285/2020      (9.83e-05, 0.000197]
# USA/WA-S290/2020      (9.83e-05, 0.000197]
#                              ...
# USA/WA-S5529/2021    (-9.83e-07, 9.83e-05]
# USA/WA-S5547/2021    (-9.83e-07, 9.83e-05]
# USA/WA-S5510/2021      (0.000492, 0.00059]
# USA/WA-S5504/2021    (-9.83e-07, 9.83e-05]
# USA/WA-S5505/2021     (0.000197, 0.000295]
# Name: gen_distance, Length: 581, dtype: category
# Categories (10, interval[float64]): [(-9.83e-07, 9.83e-05] < (9.83e-05, 0.000197] < (0.000197, 0.000295] < (0.000295, 0.000393] ... (0.00059, 0.000688] < (0.000688, 0.000786] < (0.000786, 0.000885] < (0.000885, 0.000983]]
